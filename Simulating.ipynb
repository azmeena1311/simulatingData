# %%
from sklearn.datasets import make_regression
import pandas as pd
# Out:
# C:\Users\admin\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\admin\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
features_regression,target_regression = make_regression(n_samples = 500,n_features=3,n_targets = 1)

# %%
pd.DataFrame(features_regression).head()
# Out:
#           0         1         2
# 0  0.500418  0.945031  1.996072
# 1 -1.634858 -0.066829  0.048682
# 2  0.230185  0.250678  0.114676
# 3 -0.301417  0.021423  1.102749
# 4  0.276096  0.174159 -0.060668

# %%
pd.DataFrame(target_regression).head()
# Out:
#             0
# 0  136.169586
# 1 -147.692544
# 2   28.055075
# 3   17.783098
# 4   24.348345

# %%
from sklearn.datasets import make_classification

# %%
feature_classification,targets_classification = make_classification(n_samples=500,n_features=3,
                                                                   n_informative=2,n_redundant=1,n_classes=2,weights=[.1,.2])

# %%
pd.DataFrame(feature_classification)
# Out:
#             0         1         2
# 0    0.929108 -1.300837  1.472973
# 1   -1.351439  2.965862  0.332658
# 2    1.013173 -1.435843  1.566349
# 3    0.171217  0.520020  2.022815
# 4   -0.660500  0.902540 -1.098355
# 5   -0.720797  1.211450 -0.676453
# 6   -0.724579  1.060623 -1.042342
# 7   -0.813035  1.170387 -1.215044
# 8    0.218178 -1.021551 -1.304840
# 9   -0.845078  1.942424  0.410460
# 10  -0.421761  0.336801 -1.253489
# 11  -0.423259  1.383415  1.151988
# 12  -0.408003  1.368569  1.191190
# 13  -0.820073  1.165752 -1.259601
# 14   0.128279 -0.677197 -0.943699
# 15   0.620611 -1.737168 -1.017635
# 16   0.890758 -1.280914  1.334327
# 17  -0.769218  1.979797  0.861718
# 18   1.735128 -2.338773  2.959583
# 19  -0.729578  0.922042 -1.385864
# 20   0.928679 -1.392670  1.259213
# 21   1.107546 -1.626339  1.581417
# 22  -0.094242  0.012303 -0.425218
# 23   0.181162 -0.869026 -1.131387
# 24  -0.235084  0.217797 -0.629361
# 25   0.651668 -0.980161  0.876913
# 26  -0.865674  1.477356 -0.760756
# 27   0.450950 -0.726246  0.496213
# 28  -0.693977  1.141225 -0.709254
# 29   0.009823  0.526965  1.262052
# ..        ...       ...       ...
# 470  0.181935 -0.878847 -1.150310
# 471  0.445273 -1.376051 -1.029063
# 472 -0.893632  1.868314  0.005934
# 473  0.252959 -0.419426  0.250592
# 474 -0.156325  0.679751  0.814608
# 475  1.098054 -1.495712  1.836860
# 476  0.771576 -1.237185  0.861518
# 477  0.564807 -0.749367  0.990896
# 478  0.350605 -1.261630 -1.220922
# 479 -0.093086  0.664418  1.083624
# 480  1.373859 -1.921793  2.182067
# 481 -0.698580  1.064757 -0.907685
# 482 -0.576894  0.746916 -1.054719
# 483  0.302178 -1.053931 -0.975203
# 484  0.641891 -0.932419  0.939912
# 485 -0.604373  0.639757 -1.433998
# 486  0.613613 -0.998113  0.652375
# 487  0.278839 -0.963189 -0.878347
# 488  0.706847 -0.818899  1.514233
# 489  0.686480 -0.396709  2.389453
# 490  0.607436 -0.773153  1.141231
# 491 -0.171483 -0.295196 -1.505823
# 492 -0.301822  1.392031  1.756312
# 493 -0.810146  2.029433  0.779159
# 494  0.694209 -1.676395 -0.523319
# 495  0.852145 -1.061193  1.654993
# 496  0.088327 -0.573564 -0.897088
# 497 -0.161905  1.149336  1.870249
# 498 -0.165196  0.731814  0.891929
# 499  0.039730  0.405419  1.125798
#
# [500 rows x 3 columns]

# %%
pd.DataFrame(targets_classification)
# Out:
#      0
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# 6    0
# 7    0
# 8    0
# 9    1
# 10   0
# 11   1
# 12   1
# 13   0
# 14   0
# 15   0
# 16   1
# 17   1
# 18   1
# 19   0
# 20   1
# 21   1
# 22   1
# 23   0
# 24   1
# 25   1
# 26   0
# 27   1
# 28   0
# 29   1
# ..  ..
# 470  0
# 471  0
# 472  1
# 473  1
# 474  1
# 475  1
# 476  1
# 477  1
# 478  0
# 479  1
# 480  1
# 481  0
# 482  0
# 483  0
# 484  1
# 485  0
# 486  1
# 487  0
# 488  1
# 489  1
# 490  1
# 491  1
# 492  1
# 493  1
# 494  0
# 495  1
# 496  0
# 497  1
# 498  1
# 499  1
#
# [500 rows x 1 columns]

# %%
#simulating for clustering

from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
features_clustering,target_clustering = make_blobs(n_samples=500,n_features=2,centers=3,cluster_std=0.5,shuffle = True)

# %%
plt.scatter(features_clustering[:,0],
           features_clustering[:,1])
plt.show()
